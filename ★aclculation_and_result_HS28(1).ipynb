# %% [markdown]
# <a href="https://colab.research.google.com/github/Harukokoko/Haruka-Nakagawa/blob/main/%E2%98%85aclculation_and_result_HS28(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ダウンロードデータバージョン。
# UNComtradeのAPIはいつrejectされるかわからないので、UNComtradeのサイトから無料ダウンロードしたデータ（HS：HS10、Periods：2023、輸出国：All・相手国：All、TradeFlow：Export、Mode of Transport：TOTAL modes of transport、Customs Codes：TOTAL customs procedure codes）を使用

# %% [markdown]
# ## 0. 準備

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
from typing import List, Dict, Tuple, Callable
import scipy as sp
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
import io
import os
from google.colab import files
from google.colab import drive

# %% [markdown]
# ## データダウンロード

# %%
# Google Driveをマウント
drive.mount('/content/drive')
file_path = '/content/drive/My Drive/16-research/99_Sotsuron/ex_HS8482_1995_2023.xlsx'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## データフレーム化

# %%
# ExcelファイルをPandasデータフレームに読み込む
df = pd.read_excel(file_path)

# データフレームを確認
df.head()
# Out:
#   typeCode freqCode  refPeriodId  refYear  refMonth  period  reporterCode  \
# 0        C        A     20230101     2023        52    2023            20
# 1        C        A     20230101     2023        52    2023            20
# 2        C        A     20230101     2023        52    2023            20
# 3        C        A     20230101     2023        52    2023            20
# 4        C        A     20230101     2023        52    2023            20
#
#   reporterISO reporterDesc flowCode  ... netWgt  isNetWgtEstimated grossWgt  \
# 0         AND      Andorra        X  ...  19.61              False      0.0
# 1         AND      Andorra        X  ...   2.76              False      0.0
# 2         AND      Andorra        X  ...   0.25              False      0.0
# 3         AND      Andorra        X  ...   1.00              False      0.0
# 4         AND      Andorra        X  ...  15.60              False      0.0
#
#   isGrossWgtEstimated  cifvalue  fobvalue primaryValue legacyEstimationFlag  \
# 0               False       NaN  5902.458     5902.458                    0
# 1               False       NaN    51.865       51.865                    0
# 2               False       NaN    17.995       17.995                    0
# 3               False       NaN    28.939       28.939                    0
# 4               False       NaN  5803.660     5803.660                    0
#
#   isReported  isAggregate
# 0      False         True
# 1      False         True
# 2      False         True
# 3      False         True
# 4      False         True
#
# [5 rows x 47 columns]

# %% [markdown]
# ### 抽出指定
# 商品データ、年次、HSコード、2023年、報告国は指定なし、品目は HSCode20_Cereals（第10塁　穀類）、輸出データ、貿易相手国は指定なし、積送国の指定なし、税関コード指定なし、貿易手段指定なし

# %% [markdown]
# ## データ概観

# %%
#　データ数
print("列数：",df.shape[0])
print("行数：",df.shape[1])
print("国数：",len(df['reporterDesc'].unique()))
# Out:
# 列数： 197106
# 行数： 47
# 国数： 193

# %% [markdown]
# ## 欠損値・外れ値処理

# %%
df.isnull().sum()
# Out:
# typeCode                         0
# freqCode                         0
# refPeriodId                      0
# refYear                          0
# refMonth                         0
# period                           0
# reporterCode                     0
# reporterISO                      0
# reporterDesc                     0
# flowCode                         0
# flowDesc                         0
# partnerCode                      0
# partnerISO                       0
# partnerDesc                      0
# partner2Code                     0
# partner2ISO                      0
# partner2Desc                     0
# classificationCode               0
# classificationSearchCode         0
# isOriginalClassification         0
# cmdCode                          0
# cmdDesc                          0
# aggrLevel                        0
# isLeaf                           0
# customsCode                      0
# customsDesc                      0
# mosCode                          0
# motCode                          0
# motDesc                          0
# qtyUnitCode                      0
# qtyUnitAbbr                 161725
# qty                          69892
# isQtyEstimated                   0
# altQtyUnitCode                   0
# altQtyUnitAbbr              181798
# altQty                       88194
# isAltQtyEstimated                0
# netWgt                        5737
# isNetWgtEstimated                0
# grossWgt                    104339
# isGrossWgtEstimated              0
# cifvalue                    157635
# fobvalue                         0
# primaryValue                     0
# legacyEstimationFlag             0
# isReported                       0
# isAggregate                      0
# dtype: int64

# %% [markdown]
# **欠損値が50％以上ある列を削除**

# %%
# 欠損値の割合を計算
threshold = 0.5  # 50%以上が欠損している列を削除
df = df.loc[:, df.isna().mean() < threshold]

# %% [markdown]
# **reportedDescがWorldの行を削除する**

# %%
df = df[df['reporterDesc'] != 'world']
df = df[df['partnerDesc'] != 'world']
# 結果を確認
print(f"Number of rows after filtering: {len(df)}")
# Out:
# Number of rows after filtering: 197106

# %% [markdown]
# ## **▼データ全体のネットワーク化**

# %%
# 必要な列のみ抽出
df = df[["refYear", "reporterDesc", "partnerDesc", "fobvalue"]]

# FOB値が0以下の場合は除外
df = df[df["fobvalue"] > 0]

# ノード名を小文字に統一
df["reporterDesc"] = df["reporterDesc"].str.lower()
df["partnerDesc"] = df["partnerDesc"].str.lower()

# 年ごとにグラフを作成
graphs_by_year = {}

for year, group in df.groupby("refYear"):
    # 有向グラフを作成
    G = nx.DiGraph()

    # エッジを一括追加
    edges = group[["reporterDesc", "partnerDesc", "fobvalue"]].to_dict(orient="records")
    G.add_edges_from([(edge["reporterDesc"], edge["partnerDesc"], {"weight": edge["fobvalue"]}) for edge in edges])

    # 年ごとのグラフを保存
    graphs_by_year[year] = G

    # 年ごとのグラフ情報を表示
    print(f"Year: {year}")
    print(f"  Number of nodes: {G.number_of_nodes()}")
    print(f"  Number of edges: {G.number_of_edges()}")

# 年ごとのグラフが保存された辞書
print(f"Total years processed: {len(graphs_by_year)}")
# Out:
# Year: 1995
#   Number of nodes: 212
#   Number of edges: 3190
# Year: 1996
#   Number of nodes: 211
#   Number of edges: 3424
# Year: 1997
#   Number of nodes: 209
#   Number of edges: 3466
# Year: 1998
#   Number of nodes: 211
#   Number of edges: 3666
# Year: 1999
#   Number of nodes: 213
#   Number of edges: 3798
# Year: 2000
#   Number of nodes: 225
#   Number of edges: 4389
# Year: 2001
#   Number of nodes: 228
#   Number of edges: 4626
# Year: 2002
#   Number of nodes: 225
#   Number of edges: 4700
# Year: 2003
#   Number of nodes: 227
#   Number of edges: 4898
# Year: 2004
#   Number of nodes: 226
#   Number of edges: 5156
# Year: 2005
#   Number of nodes: 230
#   Number of edges: 5314
# Year: 2006
#   Number of nodes: 231
#   Number of edges: 5547
# Year: 2007
#   Number of nodes: 232
#   Number of edges: 5767
# Year: 2008
#   Number of nodes: 228
#   Number of edges: 5845
# Year: 2009
#   Number of nodes: 231
#   Number of edges: 5924
# Year: 2010
#   Number of nodes: 231
#   Number of edges: 6132
# Year: 2011
#   Number of nodes: 232
#   Number of edges: 6226
# Year: 2012
#   Number of nodes: 236
#   Number of edges: 6456
# Year: 2013
#   Number of nodes: 233
#   Number of edges: 6499
# Year: 2014
#   Number of nodes: 238
#   Number of edges: 6570
# Year: 2015
#   Number of nodes: 233
#   Number of edges: 6659
# Year: 2016
#   Number of nodes: 232
#   Number of edges: 6863
# Year: 2017
#   Number of nodes: 233
#   Number of edges: 6858
# Year: 2018
#   Number of nodes: 234
#   Number of edges: 6991
# Year: 2019
#   Number of nodes: 235
#   Number of edges: 7105
# Year: 2020
#   Number of nodes: 235
#   Number of edges: 6922
# Year: 2021
#   Number of nodes: 239
#   Number of edges: 7054
# Year: 2022
#   Number of nodes: 231
#   Number of edges: 6987
# Year: 2023
#   Number of nodes: 234
#   Number of edges: 6996
# Total years processed: 29

# %% [markdown]
# ## **▼始点：中国→終点：アメリカ（距離４以下の経路）：subgraph**

# %%
def calculate_flow_with_stop_on_target(G, source, target, weight='weight'):
    """
    始点から終点までの流入量を計算し、終点に到達したら計算を終了する関数。
    また、終点から始点へのエッジを削除する。

    Parameters:
        G (nx.DiGraph): 重み付き有向グラフ
        source (str): 始点ノード
        target (str): 終点ノード
        weight (str): 重み属性の名前

    Returns:
        float: 終点への最終流入量
    """
    # 終点から始点へのエッジを削除
    if G.has_edge(target, source):
        G = G.copy()  # オリジナルを変更しないためにコピー
        G.remove_edge(target, source)

    # 初期化: 各ノードの流入量を0に設定
    flow = {node: 0 for node in G.nodes}
    flow[source] = 1  # 始点の流入量を1に設定

    visited = set()  # 訪問済みノードを記録

    def dfs(node):
        if node == target:
            return  # 終点に到達したら終了

        visited.add(node)
        out_edges = G.out_edges(node, data=True)
        total_weight = sum(edge_data[weight] for _, _, edge_data in out_edges)

        if total_weight == 0:  # 出力がない場合
            return

        for _, neighbor, edge_data in out_edges:
            proportion = edge_data[weight] / total_weight
            if neighbor not in visited:
                flow[neighbor] += flow[node] * proportion
                dfs(neighbor)  # 再帰的に隣接ノードを処理

    # DFSを開始
    dfs(source)

    return flow.get(target, 0)

# %%
# 基点と終点を設定
source_node = "china"
target_node = "usa"

# 年ごとの結果を保存するリスト
yearly_results = []

# 年ごとにグラフを処理
for year, G in graphs_by_year.items():

    # サブグラフ（距離4以下のノードのみを含む）
    paths_within_distance = list(nx.all_simple_paths(G, source=source_node, target=target_node, cutoff=4))
    nodes_within_paths = set(node for path in paths_within_distance for node in path)
    subgraph = G.subgraph(nodes_within_paths)

    # アメリカへの最終流入量を計算
    usa_flow = calculate_flow_with_stop_on_target(subgraph, source=source_node, target=target_node, weight="weight")

    # 直接輸出割合を計算
    if subgraph.has_edge(source_node, target_node):
        direct_weight = subgraph[source_node][target_node]["weight"]
        total_source_weight = sum(edge_data["weight"] for _, _, edge_data in subgraph.out_edges(source_node, data=True))
        direct_export_ratio = direct_weight / total_source_weight
    else:
        direct_export_ratio = 0  # 直接輸出がない場合

    # 直間比率を計算
    if usa_flow > 0:
        The_ratio_of_di = direct_export_ratio / usa_flow
        The_ratio_of_indi = 1 - The_ratio_of_di
        Indi_to_di = The_ratio_of_indi / The_ratio_of_di
    else:
        The_ratio_of_di = 0
        The_ratio_of_indi = 0
        Indi_to_di = 0

    # 中国の全輸出額を計算
    china_total_fobvalue = df[df["reporterDesc"].str.lower() == "china"]["fobvalue"].sum()

    # サブグラフ内の中国の全輸出額
    if subgraph.has_node("china"):
        china_total_export = sum(edge_data["weight"] for _, _, edge_data in subgraph.out_edges("china", data=True))
    else:
        china_total_export = 0

    # サブグラフ内の中国から米国への直接輸出額
    direct_weight = subgraph[source_node][target_node]["weight"] if subgraph.has_edge(source_node, target_node) else 0

    # アメリカへの推定流入額
    usa_final_estimation = usa_flow * china_total_export

    # 年ごとの結果を保存
    yearly_results.append({
        "Year": year,
        "Flow to USA": usa_flow,
        "Direct Export Ratio": direct_export_ratio,
        "Direct Export Amount": direct_weight,
        "Indirect to Direct Ratio": Indi_to_di,
        "China's Total FOB Value": china_total_fobvalue,
        "China's Total Export Volume": china_total_export,
        "Estimated Final Flow to USA": usa_final_estimation
    })

# データフレームに変換
results_df = pd.DataFrame(yearly_results)

# データフレームをCSVとして保存
results_df.to_csv("yearly_export_results.csv", index=False)
print("Yearly export results saved to 'yearly_export_results.csv'.")

# データフレームの表示
print(results_df.head())

# 折れ線グラフの作成
plt.figure(figsize=(12, 6))

# Flow to USAの折れ線グラフ
plt.plot(results_df["Year"], results_df["Flow to USA"], marker="o", label="Flow to USA")

# グラフの装飾
plt.title("Calculated Flow to USA from China (HS8482 Data)")
plt.xlabel("Year")
plt.ylabel("Calculated Flow")
plt.legend()
plt.grid(True)
plt.tight_layout()

# グラフを表示
plt.show()
# Out:
# Yearly export results saved to 'yearly_export_results.csv'.
#    Year  Flow to USA  Direct Export Ratio  Direct Export Amount  \
# 0  1995     0.283363             0.282416            84602953.0
# 1  1996     0.257576             0.255821            89434945.0
# 2  1997     0.284257             0.284244           112014302.0
# 3  1998     0.327357             0.327346           139911088.0
# 4  1999     0.287938             0.287918           139727590.0
#
#    Indirect to Direct Ratio  China's Total FOB Value  \
# 0                  0.003351             2.016721e+11
# 1                  0.006858             2.016721e+11
# 2                  0.000046             2.016721e+11
# 3                  0.000031             2.016721e+11
# 4                  0.000069             2.016721e+11
#
#    China's Total Export Volume  Estimated Final Flow to USA
# 0                  299568398.0                 8.488650e+07
# 1                  349599521.0                 9.004828e+07
# 2                  394078098.0                 1.120195e+08
# 3                  427409873.0                 1.399155e+08
# 4                  485302732.0                 1.397372e+08

# %% [markdown]
# *   df：全データのデータフレーム
# *   G：dfを基にreporter = row["reporterDesc"]、partner = row["partnerDesc"]、weight = row["fobvalue"]で作ったネットワーク
# *   subgraph：始点china、終点usaとしたGの部分ネットワーク

# %%
results_df.head()
# Out:
#    Year  Flow to USA  Direct Export Ratio  Direct Export Amount  \
# 0  1995     0.283363             0.282416            84602953.0
# 1  1996     0.257576             0.255821            89434945.0
# 2  1997     0.284257             0.284244           112014302.0
# 3  1998     0.327357             0.327346           139911088.0
# 4  1999     0.287938             0.287918           139727590.0
#
#    Indirect to Direct Ratio  China's Total FOB Value  \
# 0                  0.003351             2.016721e+11
# 1                  0.006858             2.016721e+11
# 2                  0.000046             2.016721e+11
# 3                  0.000031             2.016721e+11
# 4                  0.000069             2.016721e+11
#
#    China's Total Export Volume  Estimated Final Flow to USA
# 0                  299568398.0                 8.488650e+07
# 1                  349599521.0                 9.004828e+07
# 2                  394078098.0                 1.120195e+08
# 3                  427409873.0                 1.399155e+08
# 4                  485302732.0                 1.397372e+08

# %%
# 前年比変化率を計算して追加
results_df["DiIndiRatio Change (%)"] = results_df["Indirect to Direct Ratio"].pct_change() * 100

# 変化率の絶対値が大きい年を特定（例: 変化率が50%以上の年）
threshold = 50  # しきい値を設定
significant_years = results_df[results_df["DiIndiRatio Change (%)"].abs() > threshold]["Year"].tolist()

# 結果を保存するリスト
significant_results = []

# 流量変化が大きな経路を抽出
for year in significant_years:
    # 現在の年と前の年のグラフを取得
    current_graph = graphs_by_year.get(year)
    previous_graph = graphs_by_year.get(year - 1)

    if not previous_graph:
        continue  # 前年のグラフがない場合スキップ

    # 流量（エッジ重みの合計）を計算する関数
    def calculate_edge_weights(G):
        edge_weights = {}
        for edge in G.edges(data=True):
            u, v, data = edge
            weight = data.get("weight", 0)
            edge_weights[(u, v)] = weight
        return edge_weights

    # 現在の年と前の年のエッジ重みの合計を計算
    current_edge_weights = calculate_edge_weights(current_graph)
    previous_edge_weights = calculate_edge_weights(previous_graph)

    # 流量（重み）の変化率を計算
    edge_weight_changes = {}
    all_edges = set(current_edge_weights.keys()).union(previous_edge_weights.keys())
    for edge in all_edges:
        current_weight = current_edge_weights.get(edge, 0)
        previous_weight = previous_edge_weights.get(edge, 0)
        if previous_weight > 0:  # 前年の流量が0以上の場合に変化率を計算
            change_rate = ((current_weight - previous_weight) / previous_weight) * 100
        else:  # 前年の流量が0の場合
            change_rate = 100 if current_weight > 0 else 0
        edge_weight_changes[edge] = change_rate

    # 流量変化率の上位10エッジを抽出
    top_10_changes = sorted(
        edge_weight_changes.items(), key=lambda x: abs(x[1]), reverse=True
    )[:10]

    # 保存
    significant_results.append({
        "Year": year,
        "DiIndiRatio Change (%)": results_df.loc[results_df["Year"] == year, "DiIndiRatio Change (%)"].values[0],
        "Top 10 Edge Changes": {f"{edge[0]} -> {edge[1]}": change for edge, change in top_10_changes}
    })

# 最終結果を年ごとに表示
print("\nSignificant DiIndiRatio Change (%) and Edge Weight Changes:")
for result in significant_results:
    print(f"\nYear: {result['Year']} (DiIndiRatio Change (%): {result['DiIndiRatio Change (%)']:.2f}%)")
    print("Top 10 Edge Weight Changes:")
    if result["Top 10 Edge Changes"]:
        for edge, change in result["Top 10 Edge Changes"].items():
            print(f"  Edge: {edge}, Change Rate: {change:.2f}%")
    else:
        print("  No significant edge changes.")
# Out:
# Significant DiIndiRatio Change (%) and Edge Weight Changes:
#
# Year: 1996 (DiIndiRatio Change (%): 104.62%)
# Top 10 Edge Weight Changes:
#   Edge: germany -> serbia and montenegro (...2005), Change Rate: 50377.53%
#   Edge: guatemala -> world, Change Rate: 41070.00%
#   Edge: austria -> serbia and montenegro (...2005), Change Rate: 39830.72%
#   Edge: netherlands -> sudan (...2011), Change Rate: 38672.91%
#   Edge: hungary -> egypt, Change Rate: 32800.00%
#   Edge: belgium-luxembourg (...1998) -> mexico, Change Rate: 21007.59%
#   Edge: croatia -> russian federation, Change Rate: 19005.65%
#   Edge: germany -> azerbaijan, Change Rate: 14916.80%
#   Edge: czechia -> china, hong kong sar, Change Rate: 12957.63%
#   Edge: croatia -> austria, Change Rate: 11313.44%
#
# Year: 1997 (DiIndiRatio Change (%): -99.33%)
# Top 10 Edge Weight Changes:
#   Edge: hungary -> united arab emirates, Change Rate: 44500.00%
#   Edge: belgium-luxembourg (...1998) -> ukraine, Change Rate: 27861.11%
#   Edge: india -> zambia, Change Rate: 21607.29%
#   Edge: russian federation -> north macedonia, Change Rate: 13810.35%
#   Edge: finland -> china, Change Rate: 12838.78%
#   Edge: india -> belgium-luxembourg (...1998), Change Rate: 11202.81%
#   Edge: hungary -> india, Change Rate: 10850.00%
#   Edge: hungary -> rep. of korea, Change Rate: 10300.00%
#   Edge: peru -> chile, Change Rate: 9639.19%
#   Edge: ukraine -> germany, Change Rate: 9306.01%
#
# Year: 1999 (DiIndiRatio Change (%): 118.58%)
# Top 10 Edge Weight Changes:
#   Edge: jordan -> world, Change Rate: 488733.82%
#   Edge: jordan -> areas, nes, Change Rate: 242238.55%
#   Edge: japan -> ukraine, Change Rate: 46231.76%
#   Edge: türkiye -> czechia, Change Rate: 27405.43%
#   Edge: germany -> dem. rep. of the congo, Change Rate: 25824.37%
#   Edge: canada -> areas, nes, Change Rate: 10346.15%
#   Edge: chile -> mexico, Change Rate: 9880.34%
#   Edge: romania -> slovakia, Change Rate: 9833.33%
#   Edge: singapore -> solomon isds, Change Rate: 9321.75%
#   Edge: canada -> peru, Change Rate: 8003.27%
#
# Year: 2000 (DiIndiRatio Change (%): 204.53%)
# Top 10 Edge Weight Changes:
#   Edge: indonesia -> japan, Change Rate: 183713.28%
#   Edge: croatia -> austria, Change Rate: 164965.00%
#   Edge: indonesia -> singapore, Change Rate: 73444.18%
#   Edge: hungary -> indonesia, Change Rate: 46600.00%
#   Edge: hungary -> china, Change Rate: 30500.00%
#   Edge: russian federation -> united kingdom, Change Rate: 25527.44%
#   Edge: indonesia -> usa, Change Rate: 19220.12%
#   Edge: italy -> areas, nes, Change Rate: 17966.66%
#   Edge: hungary -> japan, Change Rate: 11800.00%
#   Edge: united kingdom -> croatia, Change Rate: 11470.81%
#
# Year: 2001 (DiIndiRatio Change (%): 673.20%)
# Top 10 Edge Weight Changes:
#   Edge: guyana -> world, Change Rate: 488257.14%
#   Edge: czechia -> lebanon, Change Rate: 442533.33%
#   Edge: guyana -> usa, Change Rate: 405862.86%
#   Edge: brazil -> greece, Change Rate: 264581.25%
#   Edge: philippines -> singapore, Change Rate: 148311.01%
#   Edge: romania -> china, Change Rate: 132979.42%
#   Edge: indonesia -> thailand, Change Rate: 132780.36%
#   Edge: south africa -> china, Change Rate: 96186.86%
#   Edge: new zealand -> cook isds, Change Rate: 93600.00%
#   Edge: slovakia -> japan, Change Rate: 91832.00%
#
# Year: 2002 (DiIndiRatio Change (%): -99.84%)
# Top 10 Edge Weight Changes:
#   Edge: south africa -> china, hong kong sar, Change Rate: 955425.00%
#   Edge: russian federation -> thailand, Change Rate: 428430.00%
#   Edge: thailand -> panama, Change Rate: 184700.00%
#   Edge: kazakhstan -> azerbaijan, Change Rate: 120800.00%
#   Edge: rep. of korea -> portugal, Change Rate: 91171.02%
#   Edge: türkiye -> china, Change Rate: 75722.22%
#   Edge: philippines -> germany, Change Rate: 71707.00%
#   Edge: chile -> spain, Change Rate: 59795.31%
#   Edge: other asia, nes -> hungary, Change Rate: 53786.21%
#   Edge: other asia, nes -> namibia, Change Rate: 50368.97%
#
# Year: 2003 (DiIndiRatio Change (%): -88.81%)
# Top 10 Edge Weight Changes:
#   Edge: thailand -> spain, Change Rate: 1158900.00%
#   Edge: romania -> china, Change Rate: 893626.03%
#   Edge: united arab emirates -> finland, Change Rate: 523980.00%
#   Edge: south africa -> denmark, Change Rate: 292200.00%
#   Edge: luxembourg -> norway, Change Rate: 232355.81%
#   Edge: bulgaria -> argentina, Change Rate: 189949.02%
#   Edge: canada -> algeria, Change Rate: 156929.41%
#   Edge: slovakia -> philippines, Change Rate: 115719.30%
#   Edge: ukraine -> colombia, Change Rate: 109400.00%
#   Edge: bulgaria -> areas, nes, Change Rate: 92655.07%
#
# Year: 2004 (DiIndiRatio Change (%): 1695.46%)
# Top 10 Edge Weight Changes:
#   Edge: spain -> world, Change Rate: 8544564.53%
#   Edge: australia -> denmark, Change Rate: 330800.00%
#   Edge: venezuela -> panama, Change Rate: 197723.88%
#   Edge: austria -> sri lanka, Change Rate: 157616.67%
#   Edge: denmark -> india, Change Rate: 116200.00%
#   Edge: philippines -> france, Change Rate: 99668.00%
#   Edge: thailand -> morocco, Change Rate: 80000.00%
#   Edge: romania -> azerbaijan, Change Rate: 74789.91%
#   Edge: bulgaria -> greece, Change Rate: 72166.16%
#   Edge: belarus -> azerbaijan, Change Rate: 70900.00%
#
# Year: 2005 (DiIndiRatio Change (%): 63764.78%)
# Top 10 Edge Weight Changes:
#   Edge: latvia -> sweden, Change Rate: 3840942.30%
#   Edge: slovenia -> portugal, Change Rate: 1740300.00%
#   Edge: portugal -> india, Change Rate: 812563.64%
#   Edge: russian federation -> br. virgin isds, Change Rate: 573085.71%
#   Edge: thailand -> venezuela, Change Rate: 468450.00%
#   Edge: slovenia -> china, Change Rate: 148287.50%
#   Edge: new zealand -> united kingdom, Change Rate: 125011.76%
#   Edge: türkiye -> togo, Change Rate: 117370.08%
#   Edge: viet nam -> usa, Change Rate: 76516.67%
#   Edge: bulgaria -> indonesia, Change Rate: 67512.77%
#
# Year: 2006 (DiIndiRatio Change (%): -99.99%)
# Top 10 Edge Weight Changes:
#   Edge: south africa -> indonesia, Change Rate: 7353650.00%
#   Edge: denmark -> bahrain, Change Rate: 2220300.00%
#   Edge: slovakia -> ireland, Change Rate: 741100.00%
#   Edge: russian federation -> norway, Change Rate: 445225.00%
#   Edge: united rep. of tanzania -> dem. rep. of the congo, Change Rate: 373009.09%
#   Edge: united arab emirates -> eritrea, Change Rate: 253936.36%
#   Edge: thailand -> peru, Change Rate: 224600.00%
#   Edge: bolivia (plurinational state of) -> argentina, Change Rate: 173500.00%
#   Edge: finland -> peru, Change Rate: 156100.00%
#   Edge: south africa -> colombia, Change Rate: 86463.03%
#
# Year: 2007 (DiIndiRatio Change (%): 1237.73%)
# Top 10 Edge Weight Changes:
#   Edge: thailand -> russian federation, Change Rate: 9684000.00%
#   Edge: peru -> areas, nes, Change Rate: 955742.86%
#   Edge: bangladesh -> india, Change Rate: 952000.00%
#   Edge: australia -> russian federation, Change Rate: 679115.13%
#   Edge: ukraine -> denmark, Change Rate: 330700.00%
#   Edge: latvia -> ukraine, Change Rate: 192424.74%
#   Edge: sri lanka -> singapore, Change Rate: 186880.00%
#   Edge: finland -> algeria, Change Rate: 137569.70%
#   Edge: czechia -> libya, Change Rate: 134752.00%
#   Edge: ukraine -> romania, Change Rate: 105063.20%
#
# Year: 2010 (DiIndiRatio Change (%): 275.60%)
# Top 10 Edge Weight Changes:
#   Edge: canada -> viet nam, Change Rate: 1503188.00%
#   Edge: türkiye -> world, Change Rate: 549428.03%
#   Edge: poland -> malta, Change Rate: 445200.00%
#   Edge: thailand -> nigeria, Change Rate: 290648.00%
#   Edge: romania -> nigeria, Change Rate: 256030.95%
#   Edge: china -> marshall isds, Change Rate: 200737.74%
#   Edge: costa rica -> japan, Change Rate: 199900.00%
#   Edge: singapore -> libya, Change Rate: 168728.23%
#   Edge: bulgaria -> argentina, Change Rate: 124378.95%
#   Edge: czechia -> georgia, Change Rate: 115821.62%
#
# Year: 2011 (DiIndiRatio Change (%): -97.48%)
# Top 10 Edge Weight Changes:
#   Edge: slovenia -> algeria, Change Rate: 4042900.00%
#   Edge: australia -> israel, Change Rate: 1915758.33%
#   Edge: indonesia -> south africa, Change Rate: 1704171.43%
#   Edge: gabon -> france, Change Rate: 418826.91%
#   Edge: bulgaria -> slovakia, Change Rate: 237940.00%
#   Edge: austria -> gibraltar, Change Rate: 226359.09%
#   Edge: pakistan -> china, hong kong sar, Change Rate: 224944.44%
#   Edge: finland -> bahamas, Change Rate: 209503.28%
#   Edge: ethiopia -> united arab emirates, Change Rate: 175877.02%
#   Edge: rep. of korea -> new caledonia, Change Rate: 139782.61%
#
# Year: 2012 (DiIndiRatio Change (%): 2392.13%)
# Top 10 Edge Weight Changes:
#   Edge: united arab emirates -> türkiye, Change Rate: 20088255.00%
#   Edge: denmark -> kenya, Change Rate: 2382900.00%
#   Edge: australia -> brunei darussalam, Change Rate: 1972500.00%
#   Edge: slovakia -> canada, Change Rate: 1067342.44%
#   Edge: united arab emirates -> poland, Change Rate: 361719.78%
#   Edge: chile -> united arab emirates, Change Rate: 349872.37%
#   Edge: philippines -> japan, Change Rate: 240866.24%
#   Edge: ireland -> japan, Change Rate: 224690.01%
#   Edge: romania -> croatia, Change Rate: 96380.00%
#   Edge: australia -> madagascar, Change Rate: 82215.30%
#
# Year: 2013 (DiIndiRatio Change (%): 258.34%)
# Top 10 Edge Weight Changes:
#   Edge: zambia -> netherlands, Change Rate: 12303146.48%
#   Edge: ukraine -> pakistan, Change Rate: 1485120.00%
#   Edge: singapore -> mozambique, Change Rate: 1104045.22%
#   Edge: cambodia -> world, Change Rate: 453700.00%
#   Edge: finland -> azerbaijan, Change Rate: 322341.67%
#   Edge: slovakia -> thailand, Change Rate: 297750.94%
#   Edge: bolivia (plurinational state of) -> colombia, Change Rate: 241385.10%
#   Edge: mozambique -> italy, Change Rate: 220233.33%
#   Edge: netherlands -> trinidad and tobago, Change Rate: 184175.30%
#   Edge: belarus -> south africa, Change Rate: 139200.00%
#
# Year: 2014 (DiIndiRatio Change (%): 29678.45%)
# Top 10 Edge Weight Changes:
#   Edge: thailand -> poland, Change Rate: 4365000.00%
#   Edge: spain -> denmark, Change Rate: 3839277.35%
#   Edge: serbia -> iran, Change Rate: 2180191.16%
#   Edge: ghana -> senegal, Change Rate: 491480.22%
#   Edge: uganda -> burundi, Change Rate: 448212.50%
#   Edge: croatia -> slovakia, Change Rate: 383433.33%
#   Edge: slovakia -> albania, Change Rate: 312645.38%
#   Edge: philippines -> saudi arabia, Change Rate: 297573.77%
#   Edge: spain -> netherlands, Change Rate: 196019.69%
#   Edge: uruguay -> argentina, Change Rate: 122562.50%
#
# Year: 2015 (DiIndiRatio Change (%): -60.31%)
# Top 10 Edge Weight Changes:
#   Edge: brazil -> hungary, Change Rate: 450688.89%
#   Edge: slovakia -> ireland, Change Rate: 243951.10%
#   Edge: namibia -> france, Change Rate: 235900.00%
#   Edge: spain -> el salvador, Change Rate: 161324.42%
#   Edge: denmark -> uruguay, Change Rate: 102540.00%
#   Edge: south africa -> areas, nes, Change Rate: 93045.63%
#   Edge: ireland -> india, Change Rate: 71947.40%
#   Edge: thailand -> austria, Change Rate: 69295.79%
#   Edge: new zealand -> norway, Change Rate: 60699.23%
#   Edge: norway -> congo, Change Rate: 49077.84%
#
# Year: 2016 (DiIndiRatio Change (%): 93.84%)
# Top 10 Edge Weight Changes:
#   Edge: china -> united kingdom, Change Rate: 7765868.00%
#   Edge: china -> netherlands, Change Rate: 6314645.03%
#   Edge: netherlands -> cayman isds, Change Rate: 2566911.72%
#   Edge: switzerland -> dem. rep. of the congo, Change Rate: 1778328.51%
#   Edge: norway -> world, Change Rate: 1582427.19%
#   Edge: china -> india, Change Rate: 1460455.01%
#   Edge: pakistan -> united kingdom, Change Rate: 1324933.33%
#   Edge: belgium -> eritrea, Change Rate: 854715.27%
#   Edge: china -> peru, Change Rate: 676083.07%
#   Edge: spain -> portugal, Change Rate: 435932.61%
#
# Year: 2017 (DiIndiRatio Change (%): -99.98%)
# Top 10 Edge Weight Changes:
#   Edge: slovakia -> malta, Change Rate: 10550222.49%
#   Edge: china -> italy, Change Rate: 10070763.56%
#   Edge: spain -> germany, Change Rate: 8436544.98%
#   Edge: united arab emirates -> poland, Change Rate: 4246247.70%
#   Edge: china -> sri lanka, Change Rate: 3871234.72%
#   Edge: china -> kenya, Change Rate: 3560345.24%
#   Edge: spain -> sweden, Change Rate: 2903382.66%
#   Edge: china -> côte d'ivoire, Change Rate: 2425759.38%
#   Edge: china -> china, hong kong sar, Change Rate: 2326445.70%
#   Edge: costa rica -> colombia, Change Rate: 1466479.44%
#
# Year: 2018 (DiIndiRatio Change (%): -73.63%)
# Top 10 Edge Weight Changes:
#   Edge: china -> malaysia, Change Rate: 348481795.83%
#   Edge: china -> iran, Change Rate: 188737076.47%
#   Edge: china -> brazil, Change Rate: 108424315.69%
#   Edge: china -> japan, Change Rate: 82423681.82%
#   Edge: china -> france, Change Rate: 57285209.44%
#   Edge: ukraine -> russian federation, Change Rate: 47807058.01%
#   Edge: china -> india, Change Rate: 28654086.25%
#   Edge: china -> serbia, Change Rate: 9217257.50%
#   Edge: china -> iraq, Change Rate: 5375393.33%
#   Edge: china -> canada, Change Rate: 3948080.59%
#
# Year: 2019 (DiIndiRatio Change (%): 19707.13%)
# Top 10 Edge Weight Changes:
#   Edge: portugal -> world, Change Rate: 3019953189.26%
#   Edge: north macedonia -> romania, Change Rate: 3871333.33%
#   Edge: portugal -> germany, Change Rate: 1594811.32%
#   Edge: india -> brunei darussalam, Change Rate: 1368285.26%
#   Edge: portugal -> slovakia, Change Rate: 914364.19%
#   Edge: netherlands -> areas, nes, Change Rate: 823324.76%
#   Edge: finland -> cyprus, Change Rate: 433068.60%
#   Edge: switzerland -> cuba, Change Rate: 317847.75%
#   Edge: austria -> guinea, Change Rate: 229206.27%
#   Edge: united rep. of tanzania -> kenya, Change Rate: 170503.36%
#
# Year: 2020 (DiIndiRatio Change (%): -99.93%)
# Top 10 Edge Weight Changes:
#   Edge: thailand -> indonesia, Change Rate: 105987258.78%
#   Edge: ukraine -> world, Change Rate: 47578947.57%
#   Edge: ukraine -> germany, Change Rate: 4096252.27%
#   Edge: thailand -> other asia, nes, Change Rate: 2171664.52%
#   Edge: thailand -> spain, Change Rate: 1502631.87%
#   Edge: spain -> united kingdom, Change Rate: 1252664.86%
#   Edge: thailand -> france, Change Rate: 762421.59%
#   Edge: spain -> netherlands, Change Rate: 733162.31%
#   Edge: finland -> georgia, Change Rate: 648134.07%
#   Edge: thailand -> colombia, Change Rate: 555115.75%
#
# Year: 2022 (DiIndiRatio Change (%): -95.24%)
# Top 10 Edge Weight Changes:
#   Edge: belgium -> mozambique, Change Rate: 4956628.57%
#   Edge: kazakhstan -> belarus, Change Rate: 3131062.89%
#   Edge: denmark -> areas, nes, Change Rate: 2685311.57%
#   Edge: ukraine -> russian federation, Change Rate: 2235850.64%
#   Edge: ukraine -> türkiye, Change Rate: 1340405.11%
#   Edge: poland -> armenia, Change Rate: 386093.27%
#   Edge: romania -> luxembourg, Change Rate: 348060.49%
#   Edge: latvia -> romania, Change Rate: 345974.54%
#   Edge: ukraine -> poland, Change Rate: 173570.06%
#   Edge: netherlands -> chad, Change Rate: 166335.37%
