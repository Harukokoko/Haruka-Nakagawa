# %% [markdown]
# <a href="https://colab.research.google.com/github/Harukokoko/Haruka-Nakagawa/blob/main/%E2%98%85calculation_and_result_HS28.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ダウンロードデータバージョン。
# UNComtradeのAPIはいつrejectされるかわからないので、UNComtradeのサイトから無料ダウンロードしたデータ（HS：HS10、Periods：2023、輸出国：All・相手国：All、TradeFlow：Export、Mode of Transport：TOTAL modes of transport、Customs Codes：TOTAL customs procedure codes）を使用

# %% [markdown]
# ## 0. 準備

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
from typing import List, Dict, Tuple, Callable
import scipy as sp
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
import io
import os
from google.colab import files
from google.colab import drive

# %% [markdown]
# ## 1-1. データダウンロード

# %% [markdown]
# ## 1-1-1. 今回はExcelでダウンロードしたデータをとりあえず使う

# %%
# # 手動でダウンロード
# uploaded = files.upload()

# %%
# Google Driveをマウント
drive.mount('/content/drive')
file_path = '/content/drive/My Drive/16-research/99_Sotsuron/ex_HS28_1995_2023.xlsx'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 1-2. データフレーム化

# %%
# ExcelファイルをPandasデータフレームに読み込む
df = pd.read_excel(file_path)

# データフレームを確認
df.head()
# Out:
#   typeCode freqCode  refPeriodId  refYear  refMonth  period  reporterCode  \
# 0        C        A     20230101     2023        52    2023             8
# 1        C        A     20230101     2023        52    2023             8
# 2        C        A     20230101     2023        52    2023             8
# 3        C        A     20230101     2023        52    2023             8
# 4        C        A     20230101     2023        52    2023             8
#
#   reporterISO reporterDesc flowCode  ... netWgt  isNetWgtEstimated grossWgt  \
# 0         ALB      Albania        X  ...    0.0              False      0.0
# 1         ALB      Albania        X  ...    0.0              False      0.0
# 2         ALB      Albania        X  ...    0.0              False      0.0
# 3         ALB      Albania        X  ...    0.0              False      0.0
# 4         ALB      Albania        X  ...    0.0              False      0.0
#
#   isGrossWgtEstimated  cifvalue    fobvalue primaryValue legacyEstimationFlag  \
# 0               False       NaN     600.027      600.027                    0
# 1               False       NaN  905957.447   905957.447                    0
# 2               False       NaN      53.515       53.515                    0
# 3               False       NaN   28956.347    28956.347                    0
# 4               False       NaN    3746.140     3746.140                    0
#
#   isReported  isAggregate
# 0      False         True
# 1      False         True
# 2      False         True
# 3      False         True
# 4      False         True
#
# [5 rows x 47 columns]

# %% [markdown]
# ##1-2　データ解説

# %% [markdown]
# ### 抽出指定
# 商品データ、年次、HSコード、2023年、報告国は指定なし、品目は HSCode20_Cereals（第10塁　穀類）、輸出データ、貿易相手国は指定なし、積送国の指定なし、税関コード指定なし、貿易手段指定なし

# %% [markdown]
# ## 1-2. データ概観

# %%
#　データ数
print("列数：",df.shape[0])
print("行数：",df.shape[1])
print("国数：",len(df['reporterDesc'].unique()))
# Out:
# 列数： 234493
# 行数： 47
# 国数： 203

# %% [markdown]
# ## 1-3 欠損値・外れ値処理

# %%
df.isnull().sum()
# Out:
# typeCode                         0
# freqCode                         0
# refPeriodId                      0
# refYear                          0
# refMonth                         0
# period                           0
# reporterCode                     0
# reporterISO                      0
# reporterDesc                     0
# flowCode                         0
# flowDesc                         0
# partnerCode                      0
# partnerISO                       0
# partnerDesc                      0
# partner2Code                     0
# partner2ISO                      0
# partner2Desc                     0
# classificationCode               0
# classificationSearchCode         0
# isOriginalClassification         0
# cmdCode                          0
# cmdDesc                          0
# aggrLevel                        0
# isLeaf                           0
# customsCode                      0
# customsDesc                      0
# mosCode                          0
# motCode                          0
# motDesc                          0
# qtyUnitCode                      0
# qtyUnitAbbr                 234440
# qty                         112501
# isQtyEstimated                   0
# altQtyUnitCode                   0
# altQtyUnitAbbr              234493
# altQty                      112554
# isAltQtyEstimated                0
# netWgt                      131835
# isNetWgtEstimated                0
# grossWgt                    130587
# isGrossWgtEstimated              0
# cifvalue                    189295
# fobvalue                         0
# primaryValue                     0
# legacyEstimationFlag             0
# isReported                       0
# isAggregate                      0
# dtype: int64

# %% [markdown]
# **欠損値が50％以上ある列を削除**

# %%
# 欠損値の割合を計算
threshold = 0.5  # 50%以上が欠損している列を削除
df = df.loc[:, df.isna().mean() < threshold]

# %% [markdown]
# **reportedDescがWorldの行を削除する**

# %%
df = df[df['reporterDesc'] != 'world']
df = df[df['partnerDesc'] != 'world']
# 結果を確認
print(f"Number of rows after filtering: {len(df)}")
# Out:
# Number of rows after filtering: 234493

# %% [markdown]
# # 2. ネットワーク可視化

# %% [markdown]
# ## **▼データ全体のネットワーク化**

# %%
import pandas as pd
import networkx as nx

# 必要な列のみ抽出
df = df[["refYear", "reporterDesc", "partnerDesc", "fobvalue"]]

# FOB値が0以下の場合は除外
df = df[df["fobvalue"] > 0]

# ノード名を小文字に統一
df["reporterDesc"] = df["reporterDesc"].str.lower()
df["partnerDesc"] = df["partnerDesc"].str.lower()

# 年ごとにグラフを作成
graphs_by_year = {}

for year, group in df.groupby("refYear"):
    # 有向グラフを作成
    G = nx.DiGraph()

    # エッジを一括追加
    edges = group[["reporterDesc", "partnerDesc", "fobvalue"]].to_dict(orient="records")
    G.add_edges_from([(edge["reporterDesc"], edge["partnerDesc"], {"weight": edge["fobvalue"]}) for edge in edges])

    # 年ごとのグラフを保存
    graphs_by_year[year] = G

    # 年ごとのグラフ情報を表示
    print(f"Year: {year}")
    print(f"  Number of nodes: {G.number_of_nodes()}")
    print(f"  Number of edges: {G.number_of_edges()}")

# 年ごとのグラフが保存された辞書
print(f"Total years processed: {len(graphs_by_year)}")
# Out:
# Year: 1995
#   Number of nodes: 226
#   Number of edges: 4441
# Year: 1996
#   Number of nodes: 224
#   Number of edges: 4838
# Year: 1997
#   Number of nodes: 223
#   Number of edges: 5022
# Year: 1998
#   Number of nodes: 223
#   Number of edges: 5375
# Year: 1999
#   Number of nodes: 224
#   Number of edges: 5431
# Year: 2000
#   Number of nodes: 234
#   Number of edges: 5945
# Year: 2001
#   Number of nodes: 234
#   Number of edges: 6076
# Year: 2002
#   Number of nodes: 236
#   Number of edges: 6262
# Year: 2003
#   Number of nodes: 233
#   Number of edges: 6382
# Year: 2004
#   Number of nodes: 236
#   Number of edges: 6697
# Year: 2005
#   Number of nodes: 233
#   Number of edges: 6735
# Year: 2006
#   Number of nodes: 237
#   Number of edges: 6877
# Year: 2007
#   Number of nodes: 234
#   Number of edges: 6915
# Year: 2008
#   Number of nodes: 235
#   Number of edges: 7196
# Year: 2009
#   Number of nodes: 234
#   Number of edges: 7112
# Year: 2010
#   Number of nodes: 235
#   Number of edges: 7346
# Year: 2011
#   Number of nodes: 236
#   Number of edges: 7438
# Year: 2012
#   Number of nodes: 237
#   Number of edges: 7636
# Year: 2013
#   Number of nodes: 239
#   Number of edges: 7699
# Year: 2014
#   Number of nodes: 236
#   Number of edges: 7692
# Year: 2015
#   Number of nodes: 235
#   Number of edges: 7778
# Year: 2016
#   Number of nodes: 236
#   Number of edges: 7766
# Year: 2017
#   Number of nodes: 235
#   Number of edges: 7988
# Year: 2018
#   Number of nodes: 240
#   Number of edges: 8045
# Year: 2019
#   Number of nodes: 236
#   Number of edges: 8074
# Year: 2020
#   Number of nodes: 237
#   Number of edges: 7887
# Year: 2021
#   Number of nodes: 239
#   Number of edges: 8079
# Year: 2022
#   Number of nodes: 238
#   Number of edges: 7887
# Year: 2023
#   Number of nodes: 240
#   Number of edges: 7757
# Total years processed: 29

# %% [markdown]
# ## **▼始点：中国→終点：アメリカ（距離４以下の経路）：subgraph**

# %%
# 基点と終点を設定
source_node = "china"
target_node = "usa"

# 年ごとの結果を保存するリスト
yearly_results = []

# 年ごとにグラフを処理
for year, G in graphs_by_year.items():

    # サブグラフ（距離4以下のノードのみを含む）
    paths_within_distance = list(nx.all_simple_paths(G, source=source_node, target=target_node, cutoff=4))
    nodes_within_paths = set(node for path in paths_within_distance for node in path)
    subgraph = G.subgraph(nodes_within_paths)

    # アメリカへの最終流入量を計算
    usa_flow = calculate_flow_with_stop_on_target(subgraph, source=source_node, target=target_node, weight="weight")

    # 直接輸出割合を計算
    if subgraph.has_edge(source_node, target_node):
        direct_weight = subgraph[source_node][target_node]["weight"]
        total_source_weight = sum(edge_data["weight"] for _, _, edge_data in subgraph.out_edges(source_node, data=True))
        direct_export_ratio = direct_weight / total_source_weight
    else:
        direct_export_ratio = 0  # 直接輸出がない場合

    # 直間比率を計算
    if usa_flow > 0:
        The_ratio_of_di = direct_export_ratio / usa_flow
        The_ratio_of_indi = 1 - The_ratio_of_di
        Indi_to_di = The_ratio_of_indi / The_ratio_of_di
    else:
        The_ratio_of_di = 0
        The_ratio_of_indi = 0
        Indi_to_di = 0

    # 中国の全輸出額を計算
    china_total_fobvalue = df[df["reporterDesc"].str.lower() == "china"]["fobvalue"].sum()

    # サブグラフ内の中国の全輸出額
    if subgraph.has_node("china"):
        china_total_export = sum(edge_data["weight"] for _, _, edge_data in subgraph.out_edges("china", data=True))
    else:
        china_total_export = 0

    # サブグラフ内の中国から米国への直接輸出額
    direct_weight = subgraph[source_node][target_node]["weight"] if subgraph.has_edge(source_node, target_node) else 0

    # アメリカへの推定流入額
    usa_final_estimation = usa_flow * china_total_export

    # 年ごとの結果を保存
    yearly_results.append({
        "Year": year,
        "Flow to USA": usa_flow,
        "Direct Export Ratio": direct_export_ratio,
        "Direct Export Amount": direct_weight,
        "Indirect to Direct Ratio": Indi_to_di,
        "China's Total FOB Value": china_total_fobvalue,
        "China's Total Export Volume": china_total_export,
        "Estimated Final Flow to USA": usa_final_estimation
    })

# データフレームに変換
results_df = pd.DataFrame(yearly_results)

# データフレームをCSVとして保存
results_df.to_csv("yearly_export_results.csv", index=False)
print("Yearly export results saved to 'yearly_export_results.csv'.")

# データフレームの表示
print(results_df.head())

# 折れ線グラフの作成
plt.figure(figsize=(12, 6))

# Flow to USAの折れ線グラフ
plt.plot(results_df["Year"], results_df["Flow to USA"], marker="o", label="Flow to USA")

# グラフの装飾
plt.title("Calculated Flow to USA from China (HS28 Data)")
plt.xlabel("Year")
plt.ylabel("Calculated Flow")
plt.legend()
plt.grid(True)
plt.tight_layout()

# グラフを表示
plt.show()
# Out:
# Yearly export results saved to 'yearly_export_results.csv'.
#    Year  Flow to USA  Direct Export Ratio  Direct Export Amount  \
# 0  1995     0.120301             0.120299           239703098.0
# 1  1996     0.129386             0.129384           249503096.0
# 2  1997     0.129034             0.129034           293590843.0
# 3  1998     0.140518             0.140518           312691520.0
# 4  1999     0.144553             0.144553           311678419.0
#
#    Indirect to Direct Ratio  China's Total FOB Value  \
# 0              1.626069e-05             7.508147e+11
# 1              1.424056e-05             7.508147e+11
# 2              2.186440e-06             7.508147e+11
# 3              7.384628e-10             7.508147e+11
# 4              2.848599e-08             7.508147e+11
#
#    China's Total Export Volume  Estimated Final Flow to USA
# 0                 1.992555e+09                 2.397070e+08
# 1                 1.928397e+09                 2.495066e+08
# 2                 2.275305e+09                 2.935915e+08
# 3                 2.225278e+09                 3.126915e+08
# 4                 2.156147e+09                 3.116784e+08

# %% [markdown]
# *   df：全データのデータフレーム
# *   G：dfを基にreporter = row["reporterDesc"]、partner = row["partnerDesc"]、weight = row["fobvalue"]で作ったネットワーク
# *   subgraph：始点china、終点usaとしたGの部分ネットワーク

# %%
results_df.head()
# Out:
#    Year  Flow to USA  Direct Export Ratio  Direct Export Amount  \
# 0  1995     0.120301             0.120299           239703098.0
# 1  1996     0.129386             0.129384           249503096.0
# 2  1997     0.129034             0.129034           293590843.0
# 3  1998     0.140518             0.140518           312691520.0
# 4  1999     0.144553             0.144553           311678419.0
#
#    Indirect to Direct Ratio  China's Total FOB Value  \
# 0              1.626069e-05             7.508147e+11
# 1              1.424056e-05             7.508147e+11
# 2              2.186440e-06             7.508147e+11
# 3              7.384628e-10             7.508147e+11
# 4              2.848599e-08             7.508147e+11
#
#    China's Total Export Volume  Estimated Final Flow to USA
# 0                 1.992555e+09                 2.397070e+08
# 1                 1.928397e+09                 2.495066e+08
# 2                 2.275305e+09                 2.935915e+08
# 3                 2.225278e+09                 3.126915e+08
# 4                 2.156147e+09                 3.116784e+08

# %%
# 前年比変化率を計算して追加
results_df["DiIndiRatio Change (%)"] = results_df["Indirect to Direct Ratio"].pct_change() * 100

# 変化率の絶対値が大きい年を特定（例: 変化率が50%以上の年）
threshold = 50  # しきい値を設定
significant_years = results_df[results_df["DiIndiRatio Change (%)"].abs() > threshold]["Year"].tolist()

# 結果を保存するリスト
significant_results = []

# 流量が大きく変化した経路を抽出
for year in significant_years:
    # 現在の年と前の年のグラフを取得
    current_graph = graphs_by_year.get(year)
    previous_graph = graphs_by_year.get(year - 1)

    if not previous_graph:
        continue  # 前年のグラフがない場合スキップ

    # 経路ごとの流量を計算
    def calculate_path_flows(G, source, target, cutoff=4):
        path_flows = {}
        paths = list(nx.all_simple_paths(G, source=source, target=target, cutoff=cutoff))
        for path in paths:
            flow = 1.0  # 初期値（起点の流量）
            for i in range(len(path) - 1):
                edge_data = G.get_edge_data(path[i], path[i + 1], default={"weight": 0})
                flow *= edge_data.get("weight", 0)
            path_flows[tuple(path)] = flow
        return path_flows

    # 現在の年と前の年の流量を計算
    current_path_flows = calculate_path_flows(current_graph, source_node, target_node)
    previous_path_flows = calculate_path_flows(previous_graph, source_node, target_node)

    # 流量の変化率を計算
    path_flow_changes = {}
    all_paths = set(current_path_flows.keys()).union(previous_path_flows.keys())
    for path in all_paths:
        current_flow = current_path_flows.get(path, 0)
        previous_flow = previous_path_flows.get(path, 0)
        if previous_flow > 0:  # 前年の流量が0以上の場合に変化率を計算
            change_rate = ((current_flow - previous_flow) / previous_flow) * 100
        else:  # 前年の流量が0の場合は変化率を設定（無限大を避ける）
            change_rate = 100 if current_flow > 0 else 0
        path_flow_changes[path] = change_rate

    # 流量変化率の上位10経路を抽出
    top_10_changes = sorted(
        path_flow_changes.items(), key=lambda x: abs(x[1]), reverse=True
    )[:10]

    # 保存
    significant_results.append({
        "Year": year,
        "DiIndiRatio Change (%)": results_df.loc[results_df["Year"] == year, "DiIndiRatio Change (%)"].values[0],
        "Top 10 Path Changes": {path: change for path, change in top_10_changes}
    })

# 最終結果を年ごとに表示
print("\nSignificant DiIndiRatio Change (%) (Top 10 Paths):")
for result in significant_results:
    print(f"\nYear: {result['Year']} (DiIndiRatio Change (%): {result['DiIndiRatio Change (%)']:.2f}%)")
    print("Top 10 Path Changes:")
    if result["Top 10 Path Changes"]:
        for path, change in result["Top 10 Path Changes"].items():
            print(f"  Path: {' -> '.join(path)}, Change Rate: {change:.2f}%")
    else:
        print("  No significant paths.")
# Out:
# Significant DiIndiRatio Change (%) (Top 10 Paths):
#
# Year: 1997 (DiIndiRatio Change (%): -84.65%)
# Top 10 Path Changes:
#   Path: china -> japan -> chile -> guatemala -> usa, Change Rate: 73868278.83%
#   Path: china -> zambia -> belgium-luxembourg (...1998) -> guatemala -> usa, Change Rate: 24888844.79%
#   Path: china -> chile -> russian federation -> brazil -> usa, Change Rate: 19087055.05%
#   Path: china -> chile -> guatemala -> honduras -> usa, Change Rate: 15210615.37%
#   Path: china -> austria -> ireland -> slovakia -> usa, Change Rate: 14924503.82%
#   Path: china -> zambia -> belgium-luxembourg (...1998) -> slovakia -> usa, Change Rate: 13031963.48%
#   Path: china -> norway -> chile -> guatemala -> usa, Change Rate: 12246309.12%
#   Path: china -> australia -> chile -> guatemala -> usa, Change Rate: 12006812.21%
#   Path: china -> sweden -> chile -> guatemala -> usa, Change Rate: 10552792.81%
#   Path: china -> finland -> ireland -> slovakia -> usa, Change Rate: 10186866.04%
#
# Year: 1998 (DiIndiRatio Change (%): -99.97%)
# Top 10 Path Changes:
#   Path: china -> singapore -> italy -> lithuania -> usa, Change Rate: 13051865.21%
#   Path: china -> sweden -> singapore -> italy -> usa, Change Rate: 10039334.74%
#   Path: china -> slovenia -> canada -> sweden -> usa, Change Rate: 5283543.11%
#   Path: china -> colombia -> türkiye -> lithuania -> usa, Change Rate: 3554271.82%
#   Path: china -> trinidad and tobago -> norway -> lithuania -> usa, Change Rate: 3049596.96%
#   Path: china -> slovakia -> norway -> lithuania -> usa, Change Rate: 2432946.26%
#   Path: china -> belgium-luxembourg (...1998) -> türkiye -> lithuania -> usa, Change Rate: 1807629.70%
#   Path: china -> slovenia -> canada -> argentina -> usa, Change Rate: 1777758.31%
#   Path: china -> hungary -> norway -> lithuania -> usa, Change Rate: 1679789.19%
#   Path: china -> iran -> belgium-luxembourg (...1998) -> kazakhstan -> usa, Change Rate: 1403748.48%
#
# Year: 1999 (DiIndiRatio Change (%): 3757.47%)
# Top 10 Path Changes:
#   Path: china -> lebanon -> jordan -> india -> usa, Change Rate: 9866914.79%
#   Path: china -> tunisia -> brazil -> ghana -> usa, Change Rate: 8481343.90%
#   Path: china -> jordan -> india -> ghana -> usa, Change Rate: 7961686.96%
#   Path: china -> sweden -> brazil -> ghana -> usa, Change Rate: 5759564.70%
#   Path: china -> jordan -> india -> peru -> usa, Change Rate: 4133782.73%
#   Path: china -> türkiye -> brazil -> ghana -> usa, Change Rate: 3540704.32%
#   Path: china -> iran -> jordan -> india -> usa, Change Rate: 3331885.29%
#   Path: china -> jordan -> india -> bulgaria -> usa, Change Rate: 3187454.12%
#   Path: china -> czechia -> brazil -> ghana -> usa, Change Rate: 2652698.01%
#   Path: china -> norway -> portugal -> canada -> usa, Change Rate: 2509108.50%
#
# Year: 2000 (DiIndiRatio Change (%): -91.02%)
# Top 10 Path Changes:
#   Path: china -> croatia -> russian federation -> indonesia -> usa, Change Rate: 26281653.80%
#   Path: china -> croatia -> russian federation -> rep. of korea -> usa, Change Rate: 18822843.10%
#   Path: china -> hungary -> egypt -> finland -> usa, Change Rate: 17685673.87%
#   Path: china -> hungary -> egypt -> sweden -> usa, Change Rate: 16815804.71%
#   Path: china -> philippines -> mexico -> new zealand -> usa, Change Rate: 10612350.84%
#   Path: china -> croatia -> russian federation -> united arab emirates -> usa, Change Rate: 9600783.62%
#   Path: china -> ireland -> mexico -> new zealand -> usa, Change Rate: 5118572.65%
#   Path: china -> norway -> lebanon -> belgium -> usa, Change Rate: 4701836.69%
#   Path: china -> croatia -> russian federation -> other asia, nes -> usa, Change Rate: 3472494.56%
#   Path: china -> croatia -> russian federation -> singapore -> usa, Change Rate: 3422325.16%
#
# Year: 2001 (DiIndiRatio Change (%): 798.02%)
# Top 10 Path Changes:
#   Path: china -> algeria -> netherlands -> guatemala -> usa, Change Rate: 20089780784.77%
#   Path: china -> algeria -> netherlands -> suriname -> usa, Change Rate: 5412240778.10%
#   Path: china -> israel -> trinidad and tobago -> suriname -> usa, Change Rate: 663816984.83%
#   Path: china -> algeria -> netherlands -> egypt -> usa, Change Rate: 613626098.90%
#   Path: china -> argentina -> switzerland -> guatemala -> usa, Change Rate: 407136561.79%
#   Path: china -> algeria -> netherlands -> argentina -> usa, Change Rate: 338014251.97%
#   Path: china -> algeria -> netherlands -> georgia -> usa, Change Rate: 260938988.52%
#   Path: china -> trinidad and tobago -> suriname -> usa, Change Rate: 242820923.60%
#   Path: china -> mali -> south africa -> slovenia -> usa, Change Rate: 235880369.51%
#   Path: china -> algeria -> netherlands -> ecuador -> usa, Change Rate: 197752784.71%
#
# Year: 2002 (DiIndiRatio Change (%): -98.89%)
# Top 10 Path Changes:
#   Path: china -> colombia -> france -> greece -> usa, Change Rate: 4350326621.16%
#   Path: china -> singapore -> ireland -> greece -> usa, Change Rate: 1571032311.46%
#   Path: china -> colombia -> france -> honduras -> usa, Change Rate: 891237337.67%
#   Path: china -> netherlands -> estonia -> kazakhstan -> usa, Change Rate: 183163809.49%
#   Path: china -> greece -> italy -> honduras -> usa, Change Rate: 178819158.61%
#   Path: china -> cyprus -> estonia -> kazakhstan -> usa, Change Rate: 167225317.65%
#   Path: china -> other asia, nes -> colombia -> france -> usa, Change Rate: 160367417.51%
#   Path: china -> estonia -> kazakhstan -> united arab emirates -> usa, Change Rate: 148483815.81%
#   Path: china -> colombia -> france -> kazakhstan -> usa, Change Rate: 130634582.26%
#   Path: china -> lithuania -> canada -> greece -> usa, Change Rate: 118317346.95%
#
# Year: 2003 (DiIndiRatio Change (%): 20058.57%)
# Top 10 Path Changes:
#   Path: china -> singapore -> finland -> malaysia -> usa, Change Rate: 73308875875.08%
#   Path: china -> singapore -> finland -> kuwait -> usa, Change Rate: 67721352586.09%
#   Path: china -> kenya -> south africa -> kuwait -> usa, Change Rate: 18685182210.46%
#   Path: china -> iran -> singapore -> finland -> usa, Change Rate: 15008612151.90%
#   Path: china -> romania -> singapore -> finland -> usa, Change Rate: 9614695915.77%
#   Path: china -> kenya -> south africa -> qatar -> usa, Change Rate: 4555195504.45%
#   Path: china -> morocco -> canada -> barbados -> usa, Change Rate: 3581653096.27%
#   Path: china -> singapore -> finland -> indonesia -> usa, Change Rate: 3580831551.06%
#   Path: china -> morocco -> switzerland -> qatar -> usa, Change Rate: 3482801029.68%
#   Path: china -> singapore -> finland -> ireland -> usa, Change Rate: 2915817031.46%
#
# Year: 2004 (DiIndiRatio Change (%): 1185.23%)
# Top 10 Path Changes:
#   Path: china -> switzerland -> bulgaria -> bosnia herzegovina -> usa, Change Rate: 933952799024.85%
#   Path: china -> singapore -> türkiye -> bosnia herzegovina -> usa, Change Rate: 930967772180.33%
#   Path: china -> brazil -> romania -> bosnia herzegovina -> usa, Change Rate: 745715884604.49%
#   Path: china -> denmark -> romania -> bosnia herzegovina -> usa, Change Rate: 473242177490.15%
#   Path: china -> bulgaria -> italy -> bosnia herzegovina -> usa, Change Rate: 298328535035.82%
#   Path: china -> türkiye -> czechia -> bosnia herzegovina -> usa, Change Rate: 292323118047.94%
#   Path: china -> new caledonia -> france -> bosnia herzegovina -> usa, Change Rate: 272037514270.05%
#   Path: china -> côte d'ivoire -> italy -> bosnia herzegovina -> usa, Change Rate: 177364858920.26%
#   Path: china -> jordan -> türkiye -> bosnia herzegovina -> usa, Change Rate: 171950504320.43%
#   Path: china -> brazil -> switzerland -> algeria -> usa, Change Rate: 157340804477.33%
#
# Year: 2005 (DiIndiRatio Change (%): -71.88%)
# Top 10 Path Changes:
#   Path: china -> singapore -> switzerland -> cameroon -> usa, Change Rate: 255949304373.31%
#   Path: china -> latvia -> france -> cameroon -> usa, Change Rate: 190765212676.33%
#   Path: china -> latvia -> france -> slovakia -> usa, Change Rate: 104694465395.61%
#   Path: china -> latvia -> france -> kazakhstan -> usa, Change Rate: 52373310402.30%
#   Path: china -> china, hong kong sar -> switzerland -> cameroon -> usa, Change Rate: 38357298672.22%
#   Path: china -> latvia -> france -> oman -> usa, Change Rate: 27373438380.83%
#   Path: china -> latvia -> france -> georgia -> usa, Change Rate: 19133558601.40%
#   Path: china -> latvia -> france -> bosnia herzegovina -> usa, Change Rate: 16108374571.41%
#   Path: china -> latvia -> france -> egypt -> usa, Change Rate: 15363191889.79%
#   Path: china -> latvia -> france -> angola -> usa, Change Rate: 9866041029.22%
#
# Year: 2006 (DiIndiRatio Change (%): 602.02%)
# Top 10 Path Changes:
#   Path: china -> qatar -> australia -> denmark -> usa, Change Rate: 61025012698.17%
#   Path: china -> guatemala -> china, hong kong sar -> belgium -> usa, Change Rate: 55595828949.20%
#   Path: china -> trinidad and tobago -> germany -> guatemala -> usa, Change Rate: 15040403111.21%
#   Path: china -> spain -> qatar -> australia -> usa, Change Rate: 3016152069.24%
#   Path: china -> india -> trinidad and tobago -> germany -> usa, Change Rate: 2440762566.85%
#   Path: china -> qatar -> australia -> türkiye -> usa, Change Rate: 2180785759.19%
#   Path: china -> kazakhstan -> latvia -> italy -> usa, Change Rate: 1993424957.30%
#   Path: china -> kazakhstan -> latvia -> belgium -> usa, Change Rate: 1954919490.83%
#   Path: china -> trinidad and tobago -> germany -> bulgaria -> usa, Change Rate: 1253268163.22%
#   Path: china -> colombia -> türkiye -> guatemala -> usa, Change Rate: 977275280.39%
#
# Year: 2008 (DiIndiRatio Change (%): -88.55%)
# Top 10 Path Changes:
#   Path: china -> guatemala -> spain -> georgia -> usa, Change Rate: 701204873946.49%
#   Path: china -> indonesia -> brazil -> ukraine -> usa, Change Rate: 247184753584.76%
#   Path: china -> suriname -> trinidad and tobago -> united kingdom -> usa, Change Rate: 210429213719.44%
#   Path: china -> bangladesh -> thailand -> georgia -> usa, Change Rate: 104282596466.38%
#   Path: china -> madagascar -> spain -> georgia -> usa, Change Rate: 87638508207.07%
#   Path: china -> bolivia (plurinational state of) -> spain -> georgia -> usa, Change Rate: 53493316694.29%
#   Path: china -> brazil -> ukraine -> egypt -> usa, Change Rate: 40917967196.57%
#   Path: china -> egypt -> spain -> georgia -> usa, Change Rate: 35377757935.70%
#   Path: china -> bahrain -> indonesia -> brazil -> usa, Change Rate: 31690868867.49%
#   Path: china -> estonia -> spain -> georgia -> usa, Change Rate: 26963456155.53%
#
# Year: 2009 (DiIndiRatio Change (%): -88.66%)
# Top 10 Path Changes:
#   Path: china -> colombia -> united kingdom -> nigeria -> usa, Change Rate: 633652333373.28%
#   Path: china -> spain -> colombia -> united kingdom -> usa, Change Rate: 307650846376.49%
#   Path: china -> venezuela -> netherlands -> nigeria -> usa, Change Rate: 162383879924.40%
#   Path: china -> south africa -> norway -> nigeria -> usa, Change Rate: 35934325722.00%
#   Path: china -> qatar -> india -> nigeria -> usa, Change Rate: 34791139767.20%
#   Path: china -> ireland -> pakistan -> nigeria -> usa, Change Rate: 15675004180.70%
#   Path: china -> saudi arabia -> côte d'ivoire -> nigeria -> usa, Change Rate: 8990284653.47%
#   Path: china -> colombia -> united kingdom -> nicaragua -> usa, Change Rate: 7762871069.26%
#   Path: china -> kuwait -> denmark -> nigeria -> usa, Change Rate: 6717902718.16%
#   Path: china -> qatar -> india -> serbia -> usa, Change Rate: 4635352992.83%
#
# Year: 2010 (DiIndiRatio Change (%): 1575.93%)
# Top 10 Path Changes:
#   Path: china -> lithuania -> denmark -> pakistan -> usa, Change Rate: 6057542368.66%
#   Path: china -> lithuania -> denmark -> croatia -> usa, Change Rate: 4503321813.79%
#   Path: china -> lithuania -> egypt -> côte d'ivoire -> usa, Change Rate: 3727634996.92%
#   Path: china -> barbados -> canada -> honduras -> usa, Change Rate: 2325795711.27%
#   Path: china -> lithuania -> denmark -> viet nam -> usa, Change Rate: 1710720573.09%
#   Path: china -> chile -> austria -> côte d'ivoire -> usa, Change Rate: 1065054116.68%
#   Path: china -> lithuania -> denmark -> slovakia -> usa, Change Rate: 753091134.82%
#   Path: china -> namibia -> lithuania -> denmark -> usa, Change Rate: 746114933.93%
#   Path: china -> barbados -> canada -> pakistan -> usa, Change Rate: 623177816.77%
#   Path: china -> ukraine -> united arab emirates -> south africa -> usa, Change Rate: 604412192.34%
#
# Year: 2011 (DiIndiRatio Change (%): 476.58%)
# Top 10 Path Changes:
#   Path: china -> pakistan -> thailand -> qatar -> usa, Change Rate: 7866076152545.63%
#   Path: china -> zambia -> india -> cyprus -> usa, Change Rate: 5083775128199.53%
#   Path: china -> zambia -> india -> suriname -> usa, Change Rate: 108173232855.63%
#   Path: china -> spain -> egypt -> australia -> usa, Change Rate: 67931461501.84%
#   Path: china -> cameroon -> egypt -> australia -> usa, Change Rate: 42689904028.65%
#   Path: china -> pakistan -> thailand -> czechia -> usa, Change Rate: 41145071386.49%
#   Path: china -> serbia -> egypt -> australia -> usa, Change Rate: 40229207513.46%
#   Path: china -> egypt -> australia -> suriname -> usa, Change Rate: 37092252042.98%
#   Path: china -> namibia -> zambia -> india -> usa, Change Rate: 29785976714.55%
#   Path: china -> cameroon -> greece -> slovakia -> usa, Change Rate: 19402557862.99%
#
# Year: 2012 (DiIndiRatio Change (%): -98.42%)
# Top 10 Path Changes:
#   Path: china -> serbia -> austria -> uruguay -> usa, Change Rate: 141082570701.27%
#   Path: china -> serbia -> austria -> tunisia -> usa, Change Rate: 91342526358.85%
#   Path: china -> singapore -> poland -> united arab emirates -> usa, Change Rate: 54916308936.71%
#   Path: china -> lebanon -> egypt -> thailand -> usa, Change Rate: 46248057211.49%
#   Path: china -> serbia -> austria -> guatemala -> usa, Change Rate: 17489597614.24%
#   Path: china -> australia -> serbia -> austria -> usa, Change Rate: 13743922022.96%
#   Path: china -> serbia -> austria -> ghana -> usa, Change Rate: 5155838177.34%
#   Path: china -> lebanon -> egypt -> saudi arabia -> usa, Change Rate: 5106387350.16%
#   Path: china -> serbia -> austria -> yemen -> usa, Change Rate: 4666373623.63%
#   Path: china -> lebanon -> egypt -> netherlands -> usa, Change Rate: 4563354556.26%
#
# Year: 2013 (DiIndiRatio Change (%): 256.06%)
# Top 10 Path Changes:
#   Path: china -> luxembourg -> spain -> türkiye -> usa, Change Rate: 11757989804179.75%
#   Path: china -> croatia -> france -> uganda -> usa, Change Rate: 3098939172482.65%
#   Path: china -> luxembourg -> austria -> mauritius -> usa, Change Rate: 1050749713956.06%
#   Path: china -> luxembourg -> france -> uganda -> usa, Change Rate: 393038708289.60%
#   Path: china -> malta -> france -> uganda -> usa, Change Rate: 168658696140.92%
#   Path: china -> armenia -> germany -> mauritius -> usa, Change Rate: 137258516160.00%
#   Path: china -> spain -> türkiye -> mauritius -> usa, Change Rate: 60174446094.77%
#   Path: china -> dominican rep. -> france -> uganda -> usa, Change Rate: 59924354431.38%
#   Path: china -> spain -> türkiye -> north macedonia -> usa, Change Rate: 52861122022.62%
#   Path: china -> armenia -> germany -> lao people's dem. rep. -> usa, Change Rate: 35721468842.19%
#
# Year: 2015 (DiIndiRatio Change (%): 100587656931.01%)
# Top 10 Path Changes:
#   Path: china -> luxembourg -> switzerland -> georgia -> usa, Change Rate: 161265342307.18%
#   Path: china -> sudan -> united arab emirates -> georgia -> usa, Change Rate: 50223048545.12%
#   Path: china -> ghana -> germany -> georgia -> usa, Change Rate: 43325917270.50%
#   Path: china -> serbia -> czechia -> georgia -> usa, Change Rate: 24920272426.25%
#   Path: china -> oman -> netherlands -> georgia -> usa, Change Rate: 16788525581.02%
#   Path: china -> ghana -> germany -> latvia -> usa, Change Rate: 11201160995.72%
#   Path: china -> luxembourg -> spain -> algeria -> usa, Change Rate: 10228659195.77%
#   Path: china -> dominican rep. -> spain -> algeria -> usa, Change Rate: 6061979774.33%
#   Path: china -> serbia -> czechia -> gabon -> usa, Change Rate: 4843131605.87%
#   Path: china -> china, hong kong sar -> switzerland -> georgia -> usa, Change Rate: 4381088942.52%
#
# Year: 2016 (DiIndiRatio Change (%): -99.15%)
# Top 10 Path Changes:
#   Path: china -> malaysia -> uruguay -> azerbaijan -> usa, Change Rate: 174750190885476.00%
#   Path: china -> viet nam -> russian federation -> oman -> usa, Change Rate: 30699267333511.55%
#   Path: china -> malaysia -> russian federation -> oman -> usa, Change Rate: 13489505905099.75%
#   Path: china -> ukraine -> singapore -> azerbaijan -> usa, Change Rate: 10231289748216.34%
#   Path: china -> viet nam -> singapore -> azerbaijan -> usa, Change Rate: 5348254307046.43%
#   Path: china -> saudi arabia -> italy -> azerbaijan -> usa, Change Rate: 3877762866300.02%
#   Path: china -> viet nam -> latvia -> spain -> usa, Change Rate: 3765306569983.42%
#   Path: china -> malaysia -> italy -> azerbaijan -> usa, Change Rate: 3525471395008.83%
#   Path: china -> türkiye -> russian federation -> oman -> usa, Change Rate: 3314331534876.63%
#   Path: china -> türkiye -> uruguay -> azerbaijan -> usa, Change Rate: 2903928673507.19%
#
# Year: 2017 (DiIndiRatio Change (%): -100.00%)
# Top 10 Path Changes:
#   Path: china -> mexico -> brazil -> ukraine -> usa, Change Rate: 29237009908971.00%
#   Path: china -> mexico -> denmark -> nicaragua -> usa, Change Rate: 19635721078465.81%
#   Path: china -> mexico -> brazil -> nicaragua -> usa, Change Rate: 2187271743564.46%
#   Path: china -> mexico -> belgium -> nicaragua -> usa, Change Rate: 701281644519.01%
#   Path: china -> singapore -> united arab emirates -> thailand -> usa, Change Rate: 632315496912.57%
#   Path: china -> portugal -> brazil -> ukraine -> usa, Change Rate: 361329590281.53%
#   Path: china -> mexico -> brazil -> bahrain -> usa, Change Rate: 286736826282.88%
#   Path: china -> singapore -> brazil -> ukraine -> usa, Change Rate: 222657294762.16%
#   Path: china -> mexico -> austria -> bahrain -> usa, Change Rate: 192864594672.74%
#   Path: china -> estonia -> belgium -> nicaragua -> usa, Change Rate: 161314454630.45%
#
# Year: 2018 (DiIndiRatio Change (%): 101759.57%)
# Top 10 Path Changes:
#   Path: china -> indonesia -> portugal -> norway -> usa, Change Rate: 4596875562267572.00%
#   Path: china -> ukraine -> russian federation -> tunisia -> usa, Change Rate: 2608262741920108.00%
#   Path: china -> thailand -> ukraine -> russian federation -> usa, Change Rate: 1334881742642480.50%
#   Path: china -> guatemala -> germany -> kenya -> usa, Change Rate: 1171368163440351.75%
#   Path: china -> ukraine -> russian federation -> portugal -> usa, Change Rate: 837241944469237.62%
#   Path: china -> guatemala -> germany -> jordan -> usa, Change Rate: 794614509802340.88%
#   Path: china -> ukraine -> russian federation -> kenya -> usa, Change Rate: 550311687419695.31%
#   Path: china -> canada -> ukraine -> russian federation -> usa, Change Rate: 270047743850081.09%
#   Path: china -> iran -> ukraine -> russian federation -> usa, Change Rate: 265702886184158.84%
#   Path: china -> guatemala -> germany -> pakistan -> usa, Change Rate: 241900969976120.12%
#
# Year: 2022 (DiIndiRatio Change (%): -100.00%)
# Top 10 Path Changes:
#   Path: china -> thailand -> malaysia -> spain -> usa, Change Rate: 225792493246247.66%
#   Path: china -> portugal -> canada -> spain -> usa, Change Rate: 14143086946715.60%
#   Path: china -> oman -> singapore -> spain -> usa, Change Rate: 6709758006107.55%
#   Path: china -> indonesia -> oman -> spain -> usa, Change Rate: 2251661748024.89%
#   Path: china -> iran -> oman -> spain -> usa, Change Rate: 2237698684487.24%
#   Path: china -> sweden -> oman -> spain -> usa, Change Rate: 2106568080824.09%
#   Path: china -> oman -> singapore -> guyana -> usa, Change Rate: 1628711949457.04%
#   Path: china -> thailand -> greece -> spain -> usa, Change Rate: 1588276468846.00%
#   Path: china -> thailand -> malaysia -> kuwait -> usa, Change Rate: 856727651067.11%
#   Path: china -> thailand -> malaysia -> türkiye -> usa, Change Rate: 774370036104.82%
#
# Year: 2023 (DiIndiRatio Change (%): 812170722.35%)
# Top 10 Path Changes:
#   Path: china -> south africa -> norway -> thailand -> usa, Change Rate: 7897755145134675.00%
#   Path: china -> singapore -> jordan -> thailand -> usa, Change Rate: 86282542626023.00%
#   Path: china -> romania -> mexico -> thailand -> usa, Change Rate: 60696398289704.87%
#   Path: china -> portugal -> spain -> thailand -> usa, Change Rate: 46398880932464.95%
#   Path: china -> united kingdom -> sweden -> thailand -> usa, Change Rate: 36937039955060.59%
#   Path: china -> cyprus -> greece -> thailand -> usa, Change Rate: 35692453596379.20%
#   Path: china -> brazil -> ireland -> thailand -> usa, Change Rate: 27600699826159.32%
#   Path: china -> ukraine -> greece -> thailand -> usa, Change Rate: 22820984822911.39%
#   Path: china -> ethiopia -> united arab emirates -> thailand -> usa, Change Rate: 14942609540441.79%
#   Path: china -> finland -> netherlands -> thailand -> usa, Change Rate: 12233377414976.60%
